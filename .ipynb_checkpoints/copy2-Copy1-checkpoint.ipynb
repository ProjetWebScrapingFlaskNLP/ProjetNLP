# %% [markdown]
# <h1>1. Import</h1>

# %%
#import des librairies
# %pylab inline
import numpy as np 
import pandas as pd 
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob
from textblob import Word
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.snowball import FrenchStemmer
from spellchecker import SpellChecker
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from sklearn.svm import SVC
import sklearn.naive_bayes as nb
from sklearn.ensemble import BaggingClassifier as BC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from xgboost import plot_importance, to_graphviz
from collections import Counter
from sklearn.metrics import confusion_matrix, accuracy_score, auc, precision_score, recall_score
from sklearn import feature_extraction, model_selection, svm
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, auc
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from sklearn.decomposition import TruncatedSVD
from gensim.utils import tokenize
from gensim.models import word2vec
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#ignore les warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#chargement des données
#remplacement de None par NaN
#décimal avec un point plutôt qu'une virgule dans le dataframe afin que les variables soient de type float
df = pd.read_csv(r"C:\Users\utilisateur\Documents\Projet\ProjetNLP\booking.csv", na_values=['None'], decimal=',')

# %%
#affichage des 5 premières lignes du dataframe
df.head()
# Out:
#             nom      pays favorite                 date         titre  \
# 0      Caroline  Belgique      1.0  2018-07-30 00:00:00  Exceptionnel
# 1     Olivier51    France      0.0  2020-03-16 00:00:00     Fabuleux
# 2          Marc    France      0.0  2020-03-11 00:00:00  Exceptionnel
# 3  Marie-claire    France      0.0  2020-03-08 00:00:00  Exceptionnel
# 4        Pierre    France      0.0  2020-03-06 00:00:00     Fabuleux
#
#                                          bons_points  \
# 0  Établissement recent, propre, soigne, chouette...
# 1  Accueil très chaleureux, chambre calme...tout ...
# 2  Tout bié sauf le wifi catastrophiquement lent!...
# 3                                                NaN
# 4  Excellent rapport qualité prix. Personnel très...
#
#                    mauvais_points  note type_etablissement   lieu  \
# 0                            Rien  10.0              Hôtel  Paris
# 1                             NaN   9.0              Hôtel  Paris
# 2                             NaN   9.6              Hôtel  Paris
# 3  Hôtel parfait. Quartier sympa.  10.0              Hôtel  Paris
# 4                             NaN   9.0              Hôtel  Paris
#
#    note_etablissement
# 0                 8.5
# 1                 8.5
# 2                 8.5
# 3                 8.5
# 4                 8.5

# %% [markdown]
# <h1>2. Exploration et nettoyage des données</h1>

# %%
#dimensions du dataframe
print('Le dataset a {} lignes et {} colonnes.'.format(df.shape[0], df.shape[1]))
# Out:
# Le dataset a 30946 lignes et 11 colonnes.

# %%
#affichage des variables
print('Les différents variables sont : {}.'.format(df.columns.tolist()))
# Out:
# Les différents variables sont : ['nom', 'pays', 'favorite', 'date', 'titre', 'bons_points', 'mauvais_points', 'note', 'type_etablissement', 'lieu', 'note_etablissement'].

# %%
#Existe-t-il des variables non renseignées?
df.isnull().values.any()
# Out:
# True

# %%
#affichage du nombre de valeurs manquantes selon chaque variable
df.isnull().sum()
# Out:
# nom                    395
# pays                   452
# favorite                15
# date                   410
# titre                  432
# bons_points           2359
# mauvais_points        8540
# note                   410
# type_etablissement      15
# lieu                    15
# note_etablissement      15
# dtype: int64

# %%
#type de chaque variable
df.dtypes
# Out:
# nom                    object
# pays                   object
# favorite               object
# date                   object
# titre                  object
# bons_points            object
# mauvais_points         object
# note                  float64
# type_etablissement     object
# lieu                   object
# note_etablissement    float64
# dtype: object

# %%
#statistiques descriptives du dataset
df.describe(include='all')
# Out:
#             nom    pays favorite                 date  titre  \
# count     30551   30494    30931                30536  30514
# unique     5838     127        2                 1246   9611
# top     Anonyme  France      0.0  2020-02-16 00:00:00  Bien
# freq        650   25991    30211                  205   4763
# mean        NaN     NaN      NaN                  NaN    NaN
# std         NaN     NaN      NaN                  NaN    NaN
# min         NaN     NaN      NaN                  NaN    NaN
# 25%         NaN     NaN      NaN                  NaN    NaN
# 50%         NaN     NaN      NaN                  NaN    NaN
# 75%         NaN     NaN      NaN                  NaN    NaN
# max         NaN     NaN      NaN                  NaN    NaN
#
#                                      bons_points mauvais_points          note  \
# count                                      28587          22406  30536.000000
# unique                                     22578          18151           NaN
# top     Ce client n'a pas laissé de commentaire.           Rien           NaN
# freq                                        1502            833           NaN
# mean                                         NaN            NaN      7.977607
# std                                          NaN            NaN      1.396143
# min                                          NaN            NaN      1.000000
# 25%                                          NaN            NaN      7.100000
# 50%                                          NaN            NaN      8.000000
# 75%                                          NaN            NaN      9.000000
# max                                          NaN            NaN     10.000000
#
#        type_etablissement   lieu  note_etablissement
# count               30931  30931        30931.000000
# unique                 11     18                 NaN
# top                 Hôtel  Paris                 NaN
# freq                25927  12888                 NaN
# mean                  NaN    NaN            7.903485
# std                   NaN    NaN            0.701262
# min                   NaN    NaN            5.300000
# 25%                   NaN    NaN            7.300000
# 50%                   NaN    NaN            8.000000
# 75%                   NaN    NaN            8.400000
# max                   NaN    NaN            9.800000

# %%
#suppression des accents
#cols = df.select_dtypes(include=[np.object]).columns
#df[cols] = df[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
#df

# %%
#fonction pour générer un nuage de mots
def wcloud(data,bgcolor,title):
    plt.figure(figsize = (100,100))
    wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.drop(['nom', 'pays', 'favorite', 'date', 'note', 'type_etablissement', 'lieu', 'note_etablissement'],1,inplace=True)
df.head()
# Out:
#           titre                                        bons_points  \
# 0  Exceptionnel  Établissement recent, propre, soigne, chouette...
# 1     Fabuleux   Accueil très chaleureux, chambre calme...tout ...
# 2  Exceptionnel  Tout bié sauf le wifi catastrophiquement lent!...
# 3  Exceptionnel                                                NaN
# 4     Fabuleux   Excellent rapport qualité prix. Personnel très...
#
#                    mauvais_points
# 0                            Rien
# 1                             NaN
# 2                             NaN
# 3  Hôtel parfait. Quartier sympa.
# 4                             NaN

# %%
#suppression des Nan
df = df.fillna('')
#suppression de deux phrases récurrentes dans les données
df = df[df.bons_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
df = df[df.bons_points != "Ce client n'a pas laissé de commentaire."]

df = df[df.mauvais_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
df = df[df.mauvais_points != "Ce client n'a pas laissé de commentaire."]

# %%
#itération sur l'ensemble des lignes du dataframe, affichache de l'index et son commentaire associé
for index, row in df.iterrows():
    print('index: ', index, 'col sentences:', row['titre'])
# Out:
# index:  0 col sentences: Exceptionnel
# index:  1 col sentences: Fabuleux
# index:  2 col sentences: Exceptionnel
# index:  3 col sentences: Exceptionnel
# index:  4 col sentences: Fabuleux
# index:  5 col sentences: Bien
# index:  6 col sentences: Superbe
# index:  7 col sentences: Très bien
# index:  8 col sentences: Très bien
# index:  9 col sentences: Très bien
# index:  10 col sentences: sympathique
# index:  11 col sentences: Très bien
# index:  12 col sentences: Fabuleux
# index:  13 col sentences: Très bien
# index:  14 col sentences: Nous avons adoré visiter Paris
# index:  15 col sentences: Bon séjour, nuits au calme, fenêtre ouverte sur Paris!
# index:  16 col sentences: Parfait
# index:  17 col sentences: super agreable
# index:  18 col sentences: Bien
# index:  19 col sentences: Exceptionnel
# index:  20 col sentences: Fabuleux
# index:  21 col sentences: Proche université Paris Panthéon Assas
# index:  22 col sentences: Exceptionnel
# index:  23 col sentences: Un petit bout de paradis en plein cœur de Paris
# index:  24 col sentences: Exceptionnel
# index:  25 col sentences: Fabuleux
# index:  26 col sentences: Très bien
# index:  27 col sentences: Très bien
# index:  28 col sentences: Bien
# index:  29 col sentences: Quartier Mouffetard parfait, magnifique
# index:  30 col sentences: Très très bien !!!
# index:  31 col sentences: Bien
# index:  32 col sentences: Fabuleux
# index:  33 col sentences: Exceptionnel
# index:  34 col sentences: Halte parisienne parfaite
# index:  35 col sentences: Tres bonne adresse ...
# index:  36 col sentences: Bien
# index:  37 col sentences: Superbe
# index:  38 col sentences: A PART CE CONTRETEMPS QU ON AURAIT PU M INFORMER HOTEL NICKEL
# index:  39 col sentences: Fabuleux
# index:  40 col sentences: Établissement de qualité
# index:  41 col sentences: Fabuleux
# index:  42 col sentences: Bien
# index:  43 col sentences: Fabuleux
# index:  44 col sentences: Très bien
# index:  45 col sentences: Exceptionnel
# index:  46 col sentences: Excellente prestation à paris
# index:  47 col sentences: Exceptionnel
# index:  48 col sentences: Une nuit sur les toits de Paris...
# index:  49 col sentences: Soirée et nuit agréables.
# index:  50 col sentences: Bien
# index:  51 col sentences: Fabuleux
# index:  52 col sentences: Exceptionnel
# index:  53 col sentences: Exceptionnel
# index:  54 col sentences: Séjour agréable hormis le problème de lavabo
# index:  55 col sentences: Excellent emplacement
# index:  56 col sentences: Exceptionnel
# index:  57 col sentences: Excellent
# index:  128 col sentences: hotel agèable dans un quartier animè
# index:  129 col sentences: On peut y aller sans hésiter, mais il faudrait revoir l'isolation phonique des chambres...
# index:  130 col sentences: Exceptionnel
# index:  131 col sentences: Superbe
# index:  132 col sentences: Hotel sympathique bien situé
# index:  133 col sentences: Séjour très agréable dans cet hôtel accueillant
# index:  134 col sentences: Très bien
# index:  135 col sentences: Je recommande !
# index:  136 col sentences: Un Paris parisien.
# index:  137 col sentences: Fabuleux
# index:  138 col sentences: Fabuleux
# index:  139 col sentences: :-)
# index:  140 col sentences: Bien
# index:  141 col sentences: Exceptionnel
# index:  142 col sentences: A recommander sans hésitation.
# index:  143 col sentences: Bien
# index:  144 col sentences: moyen
# index:  145 col sentences: Fabuleux
# index:  146 col sentences: personnel chaleueux, bon rapport qualité prix, bonne situation géographique
# index:  147 col sentences: Exceptionnel
# index:  148 col sentences: l'endroit est vraiment sympa, la rue Mouffetard est top à tout niveau
# index:  149 col sentences: Superbe
# index:  150 col sentences: Bien
# index:  151 col sentences: Séjour de 3 jours essentiellement nocturne, confortable.
# index:  152 col sentences: mauvais rapport qualité prix
# index:  153 col sentences: Bien
# index:  154 col sentences: Exceptionnel
# index:  155 col sentences: Séjour très agréable
# index:  156 col sentences: Très bien
# index:  157 col sentences: hôtel agréable, bien situé.
# index:  158 col sentences: Bien
# index:  159 col sentences: Très bien
# index:  160 col sentences: Bel établissement bien situé
# index:  161 col sentences: Bien
# index:  162 col sentences: Exceptionnel
# index:  163 col sentences: Exceptionnel
# index:  164 col sentences: Exceptionnel
# index:  165 col sentences: Très bien
# index:  166 col sentences: Superbe
# index:  167 col sentences: Exceptionnel
# index:  168 col sentences: Fabuleux
# index:  169 col sentences: Je recommande
# index:  170 col sentences: Bon séjour, je.recommande.
# index:  171 col sentences: un petit hôtel sympa dans un quartier vivant
# index:  172 col sentences: Très bien
# index:  173 col sentences: Exceptionnel
# index:  174 col sentences: Bon plan !
# index:  175 col sentences: Bien
# index:  176 col sentences: Très bien
# index:  177 col sentences: Correct sans plus. Je n'y retournerai pas.
# index:  178 col sentences: Tel que je l'attendais
# index:  179 col sentences: Excellent hôtel, je recommande.
# index:  180 col sentences: quartier très sympa, hotel bon rapport qualité prix si chambre sur cour
# index:  181 col sentences: Très bien
# index:  182 col sentences: Superbe
# index:  183 col sentences: Bien
# index:  184 col sentences: Bien
# index:  185 col sentences: bon qualité prix, accueil sympas et hotel confortable bien placé
# index:  186 col sentences: Séjour très agréable.
# index:  187 col sentences: Bien
# index:  188 col sentences: Très bien
# index:  189 col sentences: PEUT MIEUX FAIRE
# index:  190 col sentences: Bien
# index:  191 col sentences: Un excellent qualité-prix
# index:  192 col sentences: Emplacement idéal pour faire un maximum de choses à pied, tout près du quartier latin.
# index:  193 col sentences: Bel hôtel bien situé
# index:  194 col sentences: Séjour Paris
# index:  195 col sentences: Très bien
# index:  196 col sentences: Exceptionnel
# index:  197 col sentences: Superbe
# index:  198 col sentences: Excellent
# index:  199 col sentences: Exceptionnel
# index:  200 col sentences: bon petit hotel dans un quartier sympa
# index:  201 col sentences: week-end à Paris
# index:  202 col sentences: Un hôtel bien situé mais un confort très moyen
# index:  203 col sentences: Très bien pour le rapport qualité/prix, dans le quartier de la rue Mouffetard
# index:  204 col sentences: PARFAIT ET EXCELLENT BRAVO
# index:  205 col sentences: Agréable
# index:  206 col sentences: excellent rapport qualité prix dans un quartier où il fait bon vivre
# index:  207 col sentences: Superbe
# index:  208 col sentences: Superbe
# index:  209 col sentences: Établissement bien placé. Chambre propre et calme. Personnels très accueillants.
# index:  210 col sentences: très bien, un peu cher quand même
# index:  211 col sentences: Séjour agréable au calme, dans un bon lit et dans un quartier sympa.
# index:  212 col sentences: Très bien
# index:  213 col sentences: Décevant
# index:  214 col sentences: Passable
# index:  215 col sentences: La chambre 14 est à éviter elle subit les nuisances sonores des pompes à Chaleur de l’hôtel
# index:  216 col sentences: Passable
# index:  217 col sentences: Agréable
# index:  218 col sentences: beaucoup trop étroit pour un 3 étoiles.
# index:  219 col sentences: ça passe ....
# index:  220 col sentences: De rêve
# index:  221 col sentences: Bien
# index:  222 col sentences: Etablissement propre, très bien situé, calme. Excellent petit déjeuner.
# index:  223 col sentences: Bien
# index:  224 col sentences: bien
# index:  225 col sentences: agréable
# index:  226 col sentences: Agréable
# index:  227 col sentences: Bien
# index:  228 col sentences: Séjour satisfaisant.
# index:  229 col sentences: Très bien
# index:  230 col sentences: Très bien
# index:  231 col sentences: Très bien
# index:  232 col sentences: notre séjour c'est bien passé
# index:  233 col sentences: Très bien
# index:  234 col sentences: Bon rapport qualite prix
# index:  235 col sentences: Banale
# index:  236 col sentences: Très bien
# index:  237 col sentences: satisfaisant dans l'ensemble
# index:  238 col sentences: Agreable
# index:  239 col sentences: Bon hôtel pour déplacement professionnel à faibles coûts
# index:  240 col sentences: Très bien
# index:  241 col sentences: Bon séjour
# index:  242 col sentences: Très bien
# index:  243 col sentences: Très bien
# index:  244 col sentences: Pour seulement quelques nuits , ça va très bien.
# index:  245 col sentences: Bien
# index:  246 col sentences: A recommander
# index:  247 col sentences: Bon
# index:  248 col sentences: Très bien
# index:  249 col sentences: Bien
# index:  250 col sentences: Bien
# index:  251 col sentences: Ok
# index:  252 col sentences: detente assurée dans le calme mais dans un quartier vivant
# index:  253 col sentences: Séjour agréable, très proche Montparnasse.
# index:  254 col sentences: Bien
# index:  255 col sentences: Petit hôtel simple et agréable, superbe emplacement et personnel très sympathique,
# index:  256 col sentences: Agréable
# index:  257 col sentences: Bien
# index:  258 col sentences: Hotel de quartier simple, correct rapport prix/qualité de prestation
# index:  259 col sentences: Bien
# index:  260 col sentences: Bien
# index:  261 col sentences: hôtel très agréable mais un peu vieillissant au niveau salle de bain
# index:  262 col sentences: Très bien
# index:  263 col sentences: Agréable
# index:  264 col sentences: Sans probleme
# index:  265 col sentences: Bien
# index:  266 col sentences: Un peu déçue par rapport au prix
# index:  267 col sentences: Nuit de transit satisfaisante
# index:  268 col sentences: Bien
# index:  269 col sentences: Bon rapport qualité/prix
# index:  270 col sentences: Très bien
# index:  271 col sentences: Très correct
# index:  272 col sentences: Agréable
# index:  273 col sentences: Agréable séjour
# index:  274 col sentences: Le séjour était fort charmant.
# index:  275 col sentences: Bien
# index:  276 col sentences: Très bien
# index:  277 col sentences: tres bien
# index:  278 col sentences: Bon rapport qualité/prix
# index:  279 col sentences: Très bien
# index:  280 col sentences: Très bien
# index:  281 col sentences: Très bien
# index:  282 col sentences: Bien
# index:  283 col sentences: Très bon rapport qualité prix !
# index:  284 col sentences: sejour de 3 jours correct
# index:  285 col sentences: Agréable
# index:  286 col sentences: Bien
# index:  287 col sentences: Je déconseille cet hôtel
# index:  288 col sentences: Bien
# index:  289 col sentences: Emplacement pratique
# index:  290 col sentences: Très bon
# index:  291 col sentences: agréable séjour
# index:  292 col sentences: Une étape agréable et confortable dans un environnement calme. Très bien.
# index:  293 col sentences: Bien
# index:  294 col sentences: Montant cher le petit déjeuner devrait être inclus.
# index:  295 col sentences: Séjour agréable comme d’habitude !
# index:  296 col sentences: Très bref
# index:  297 col sentences: bon séjour mais court
# index:  298 col sentences: Bien
# index:  299 col sentences: Bien
# index:  300 col sentences: Avis mitigé et prix élevé
# index:  301 col sentences: Calme et très bien situé.
# index:  302 col sentences: Je recommande vivement
# index:  303 col sentences: Plutôt satisfait grâce au personnel agreable
# index:  304 col sentences: Bien
# index:  305 col sentences: Confortable et personnel très sympathique
# index:  306 col sentences: Bien
# index:  307 col sentences: bien
# index:  308 col sentences: CORRECT POUR UNE NUIT DE TRANSIT
# index:  309 col sentences: Très bon hôtel relativement à la moyenne des hôtels présents dans la zone. Juste ce qu'il faut
# index:  310 col sentences: Agréable
# index:  311 col sentences: bon rapport qualité prix
# index:  312 col sentences: Très bon rapport qualité-prix
# index:  313 col sentences: Bien
# index:  314 col sentences: Bon sejour
# index:  315 col sentences: Une nuit à Paris
# index:  316 col sentences: Hôtel sympathique
# index:  317 col sentences: J'y reviens toujours avec plaisir
# index:  318 col sentences: Bien
# index:  319 col sentences: Très bien
# index:  320 col sentences: Bien
# index:  321 col sentences: Très bien
# index:  322 col sentences: Bien
# index:  323 col sentences: Agréable
# index:  324 col sentences: Agréable
# index:  325 col sentences: Bien
# index:  326 col sentences: Bon
# index:  327 col sentences: Chambre et quartier agréable mais salle de bain un peu petite et petit déjeuner trop cher !
# index:  328 col sentences: Ouïe sensible s'abstenir
# index:  329 col sentences: Bon
# index:  330 col sentences: Agréable
# index:  331 col sentences: La lieu dans cette rue etait parfait.
# index:  332 col sentences: Bien
# index:  333 col sentences: séjour agreable
# index:  334 col sentences: Établissement très bien pour 2 à 3 nuits
# index:  335 col sentences: Bon séjour
# index:  336 col sentences: Parfait pour 1 nuit.
# index:  337 col sentences: Bien
# index:  338 col sentences: Bien
# index:  339 col sentences: Agréable
# index:  340 col sentences: Très bien
# index:  341 col sentences: Bon
# index:  342 col sentences: Bien
# index:  343 col sentences: Quartier sympa, hôtel basique
# index:  344 col sentences: Bien
# index:  345 col sentences: Bien
# index:  346 col sentences: correct
# index:  347 col sentences: Bien
# index:  348 col sentences: Une nuit pas plus
# index:  349 col sentences: Cela dépanne
# index:  350 col sentences: Bon
# index:  351 col sentences: Agréable
# index:  352 col sentences: correct
# index:  353 col sentences: Bien
# index:  354 col sentences: Venue via la gare Montparnasse pour amis et spectacle j'étais à portée de train, bus et métro
# index:  355 col sentences: Qaund on aime euh.... on ne "conte" pas!
# index:  356 col sentences: Très bien
# index:  357 col sentences: Bien
# index:  358 col sentences: Très convenable pour une courte étape
# index:  359 col sentences: Bien
# index:  360 col sentences: Très bien
# index:  361 col sentences: Côté pratique : ok mais quel dommage d' avoir un environnement si bruyant.
# index:  362 col sentences: Très bien
# index:  363 col sentences: Convenable.
# index:  364 col sentences: Séjour pour passer des épreuves orales d'examen . Besoin de calme
# index:  365 col sentences: Bien
# index:  366 col sentences: Agréable
# index:  367 col sentences: rapport qualité prix honnete
# index:  368 col sentences: Bon séjour parisien avec ma fille mais facture hôtel élevée par rapport aux projections faites sur B
# index:  369 col sentences: Pas mal pour un séjour d'un jour.
# index:  370 col sentences: Je n'y retournerai plus
# index:  371 col sentences: tres bon rapport qualite prix
# index:  372 col sentences: Bien
# index:  373 col sentences: Mauvais rapport qualité prix (ANNE)
# index:  374 col sentences: L’hôtel est très bien situé mais mal insonorisé
# index:  375 col sentences: Agréable
# index:  376 col sentences: Bien situé, bon accueil - Salle de douche à revoir et bruit des portes
# index:  377 col sentences: Agréable
# index:  378 col sentences: Bon
# index:  379 col sentences: Très bien
# index:  380 col sentences: Hôtel bien situé et agréable mais pas de clim en période de canicule.
# index:  381 col sentences: Bon
# index:  382 col sentences: Bon
# index:  383 col sentences: Bien
# index:  384 col sentences: Agréable
# index:  385 col sentences: Bien
# index:  386 col sentences: Une adresse qui est pratique pour un séjour sans prétention
# index:  387 col sentences: Hors de prix pour une chambre minuscule
# index:  388 col sentences: Bien
# index:  389 col sentences: Insonorisation catastrophique
# index:  390 col sentences: Agréable
# index:  391 col sentences: Agréable
# index:  392 col sentences: Agréable
# index:  393 col sentences: Bon
# index:  394 col sentences: Chambre très propre et literie confortable ; bien pour une nuit. Quartier très agréable et sûr.
# index:  395 col sentences: Sympa mais bruyant !
# index:  396 col sentences: Bien
# index:  397 col sentences: Ras
# index:  398 col sentences: Petit hotel sympa pour quelques jours
# index:  399 col sentences: Bien
# index:  400 col sentences: Je ne pense pas y retourner de plus le prix de 129€ avec petit déjeuner
# index:  401 col sentences: Très bien
# index:  402 col sentences: Lieu était idéal par rapport à notre RV mais prix trop élevé par rapport au confort.
# index:  403 col sentences: Très bien
# index:  404 col sentences: Si je devais revenir à Paris 14ème, je pourrais revenir dans cet hôtel
# index:  405 col sentences: Bien
# index:  406 col sentences: sympa
# index:  407 col sentences: Bien
# index:  408 col sentences: Très bon rapport qualité prix et situation.
# index:  409 col sentences: Bien
# index:  410 col sentences: Bien
# index:  411 col sentences: Très bien. Situation rêvée pour accès Orly us
# index:  412 col sentences: Un hôtel à recommander
# index:  413 col sentences: Agréable
# index:  414 col sentences: Bien
# index:  415 col sentences: Agréable
# index:  416 col sentences: Bien
# index:  417 col sentences: Bien
# index:  418 col sentences: Bien
# index:  419 col sentences: Bien
# index:  420 col sentences: Bon
# index:  421 col sentences: Quartier agréable mais hôtel à rénover (insonorisation)
# index:  422 col sentences: Bien
# index:  423 col sentences: Agréable
# index:  424 col sentences: Réservation pas claire
# index:  425 col sentences: Bien
# index:  426 col sentences: Bien
# index:  427 col sentences: Bien
# index:  428 col sentences: Parfait pour une ou deux nuits
# index:  429 col sentences: Très bonne option pour prendre un train tôt le lendemain, avec un excellent rapport qualite prix
# index:  430 col sentences: Bien
# index:  431 col sentences: Bien
# index:  432 col sentences: Bien
# index:  433 col sentences: Bon
# index:  434 col sentences: Bien
# index:  435 col sentences: Bien
# index:  436 col sentences: Agréable
# index:  437 col sentences: Bon
# index:  438 col sentences: Bien
# index:  439 col sentences: Bien
# index:  440 col sentences: rapport qualité/prix imbattable pour l'emplacement
# index:  441 col sentences: Séjour pro
# index:  442 col sentences: séjour très plaisant.
# index:  443 col sentences: Très bien pour un séjour à Paris
# index:  444 col sentences: Plus que parfait
# index:  445 col sentences: Parfait
# index:  446 col sentences: Bon sejour
# index:  447 col sentences: Très bien
# index:  448 col sentences: Mon adresse à Paris
# index:  449 col sentences: Exceptionnel
# index:  450 col sentences: Hôtel très agréable
# index:  451 col sentences: Bon rapport qualité prix
# index:  452 col sentences: Top
# index:  453 col sentences: Fabuleux
# index:  454 col sentences: Sympa
# index:  455 col sentences: Exceptionnel
# index:  456 col sentences: Jolie décoration, charmant endroit
# index:  457 col sentences: Exceptionnel
# index:  458 col sentences: Fabuleux
# index:  459 col sentences: Top
# index:  460 col sentences: Très bien
# index:  461 col sentences: Très bien
# index:  462 col sentences: Fabuleux
# index:  463 col sentences: Séjour efficace pour motif professionnel : calme, bien situé, propre
# index:  464 col sentences: Encore une belle expérience
# index:  465 col sentences: Nous reviendrons :-))
# index:  466 col sentences: Exceptionnel
# index:  467 col sentences: Nuit parfaite !
# index:  468 col sentences: Exceptionnel
# index:  469 col sentences: Bon Séjour
# index:  470 col sentences: Exceptionnel
# index:  471 col sentences: Merci et bravo
# index:  472 col sentences: Une bonne adresse à avoir à Paris!
# index:  473 col sentences: Excellent rapport qualité prix
# index:  474 col sentences: Nous avons bien aimé votre décoration intérieure, chargée mais nous faisant sentir comme à la maison
# index:  475 col sentences: hotel très sympathique
# index:  476 col sentences: Une découverte...
# index:  477 col sentences: Exceptionnel
# index:  478 col sentences: Hôtel bien situé, dans un quartier calme, proche de la station de metro Sébastopol.
# index:  479 col sentences: Très bien
# index:  480 col sentences: Fabuleux
# index:  481 col sentences: Une bonne adresse
# index:  482 col sentences: Très bien
# index:  483 col sentences: Un excellent rapport qualité prix
# index:  484 col sentences: Très satisfait
# index:  485 col sentences: Une très bonne adresse à Paris, idéalement situé et accueil très chaleureux.
# index:  486 col sentences: Superbe
# index:  487 col sentences: Fabuleux
# index:  488 col sentences: Exceptionnel
# index:  489 col sentences: Très bien
# index:  490 col sentences: Exceptionnel
# index:  491 col sentences: Très bon séjour
# index:  492 col sentences: Au top
# index:  493 col sentences: Très bien
# index:  494 col sentences: Exceptionnel
# index:  495 col sentences: Hôtel dépaysant avec une âme et un personnel attentif
# index:  496 col sentences: Difficile, il y a tant de choses à dire...
# index:  497 col sentences: Exceptionnel
# index:  498 col sentences: Du service et l'acceuil !
# index:  499 col sentences: très agréable
# index:  500 col sentences: Fabuleux
# index:  501 col sentences: Exceptionnel
# index:  502 col sentences: Super hotel au coeur de Paris
# index:  503 col sentences: Exceptionnel
# index:  504 col sentences: Exceptionnel
# index:  505 col sentences: Très bien
# index:  506 col sentences: Un bon rapport qualité/prix pour un week-end en amoureux au centre de Paris.
# index:  507 col sentences: Parfait
# index:  508 col sentences: Parfait
# index:  509 col sentences: Exceptionnel
# index:  510 col sentences: Fabuleux
# index:  511 col sentences: Au top
# index:  512 col sentences: Personnel très agréable. Bien situé.
# index:  513 col sentences: Fabuleux
# index:  514 col sentences: Très bonne option pour vacances ou travail
# index:  515 col sentences: Exceptionnel
# index:  516 col sentences: conforme aux attentes
# index:  517 col sentences: Fabuleux
# index:  518 col sentences: Très bon séjour et agréable nuit dans cet hôtel
# index:  519 col sentences: Un lieu hors du commun servi par une équipe aux petits soins.
# index:  520 col sentences: Un moment agréable dans un environnement chaleureux.
# index:  521 col sentences: Superbe
# index:  522 col sentences: Agréable hôtel
# index:  523 col sentences: Exceptionnel
# index:  524 col sentences: Adresse à retenir
# index:  525 col sentences: Très bien
# index:  526 col sentences: Très bien
# index:  527 col sentences: Fabuleux
# index:  528 col sentences: Très bien
# index:  529 col sentences: Fabuleux
# index:  530 col sentences: Très bien
# index:  531 col sentences: Très agréable
# index:  532 col sentences: En balade pendant la manif
# index:  533 col sentences: Une bonne nuit dans un bon lit dans un bon hotel
# index:  534 col sentences: A conseiller sans hesitation
# index:  535 col sentences: Noël au Roubaix !
# index:  536 col sentences: Très bien
# index:  537 col sentences: Exceptionnel
# index:  538 col sentences: Exceptionnel
# index:  539 col sentences: Très bien
# index:  540 col sentences: Exceptionnel
# index:  541 col sentences: Très bien
# index:  542 col sentences: Exceptionnel
# index:  543 col sentences: Très bien
# index:  544 col sentences: Séjour agréable, j'ai du coup réservé mon prochain séjour dans le même hôtel.
# index:  545 col sentences: Exceptionnel
# index:  546 col sentences: Très bon emplacement
# index:  547 col sentences: Magnifique week-end à Paris dans un cadre haut en couleur et proche de toutes le commodités
# index:  548 col sentences: Hôtel à recommander
# index:  549 col sentences: Exceptionnel
# index:  550 col sentences: Fabuleux
# index:  551 col sentences: Exceptionnel
# index:  552 col sentences: Très bien. Je reviendrai l'année prochaine.
# index:  553 col sentences: Très agréable séjour, dans un cadre à la décoration originale et bien pensée, un monde à découvrir
# index:  554 col sentences: Très bon rapport qualité prix
# index:  555 col sentences: Exceptionnel
# index:  556 col sentences: Très sympa. Je n'hésiterai pas à revenir
# index:  557 col sentences: L’attention et le calme
# index:  558 col sentences: Fabuleux
# index:  559 col sentences: Professionnalisme garanti. Très bon emplacement
# index:  560 col sentences: Super hôtel ! Une pépite à Paris !
# index:  561 col sentences: Excellent séjour dans un hôtel vraiment très bien situé au coeur de Paris et cependant très calme.
# index:  562 col sentences: Fabuleux
# index:  563 col sentences: Bel hôtel bien situé
# index:  564 col sentences: Hôtel très bien placé, la chambre offre à la fois un confort et une décoration unique et originale.
# index:  565 col sentences: Parfait !
# index:  566 col sentences: Fabuleux
# index:  567 col sentences: Excellent accueil
# index:  568 col sentences: Très bon souvenir
# index:  569 col sentences: Exceptionnel
# index:  570 col sentences: Accueillant et souriant
# index:  571 col sentences: Séjour plus qu’agreable.
# index:  572 col sentences: Exceptionnel
# index:  573 col sentences: Très bien
# index:  574 col sentences: Très bien
# index:  575 col sentences: hôtel décoré avec beaucoup de fantaisie .
# index:  576 col sentences: Superbe
# index:  577 col sentences: J'ai adoré le petit-déjeuner
# index:  578 col sentences: Exceptionnel
# index:  579 col sentences: Fabuleux
# index:  580 col sentences: Belles chambres rénovées avec goût, accueil parfait, bon emplacement et magnifique petit déj
# index:  581 col sentences: Bonne expérience
# index:  582 col sentences: court séjour, idéal pour visiter le Paris de Beaubourg, flâner dans le Marais et faire du shopping
# index:  583 col sentences: Bon rapport qualité prix
# index:  584 col sentences: Exceptionnel
# index:  585 col sentences: Exceptionnel
# index:  586 col sentences: excellent
# index:  587 col sentences: Excellent
# index:  588 col sentences: enregitré sur mon carnet bonnes addresses
# index:  589 col sentences: Fabuleux
# index:  590 col sentences: Idéal pour les voyageurs seuls.
# index:  591 col sentences: ,
# index:  592 col sentences: A recommander
# index:  593 col sentences: Fabuleux
# index:  594 col sentences: Je recommande!
# index:  595 col sentences: Très bien
# index:  596 col sentences: Très bon rapport qualité prix
# index:  597 col sentences: Séjour agréable, simple et facilité par un accueil au top
# index:  598 col sentences: Très chouette!
# index:  599 col sentences: Parfait
# index:  600 col sentences: Fabuleux
# index:  601 col sentences: Exceptionnel
# index:  602 col sentences: Très chouette petit hôtel à l'ambiane chaleureuse et aux prestations impeccables. Parfait.
# index:  603 col sentences: hotel agréable , bien situé avec un rapport qualité / prix satisfaisant
# index:  604 col sentences: Parfait pour un séjour en cœur de ville
# index:  605 col sentences: Très bien
# index:  606 col sentences: Super
# index:  607 col sentences: Très agréable
# index:  608 col sentences: Fabuleux
# index:  609 col sentences: Exceptionnel
# index:  610 col sentences: Un hôtel à la déco originale et chaleureuse, très bien placé en plein de coeur de Paris.
# index:  611 col sentences: Fabuleux
# index:  612 col sentences: Très bien
# index:  613 col sentences: Excellent rapport qualité prix.
# index:  614 col sentences: Formidable
# index:  615 col sentences: Très bon rapport qualité prix
# index:  616 col sentences: Parfait
# index:  617 col sentences: Très bon séjour
# index:  618 col sentences: Pop art
# index:  619 col sentences: bon séjour sans problème et bon accueil
# index:  620 col sentences: Nous reviendrons
# index:  621 col sentences: Exceptionnel
# index:  622 col sentences: Fabuleux
# index:  623 col sentences: Exceptionnel
# index:  624 col sentences: Un accueil extrêmement agréable et chaleureux dans un décor très original, au coeur même de Paris.
# index:  926 col sentences: Passer un aspirateur bruyant à 16h pas du tout agréable
# index:  927 col sentences: Séjour agréable
# index:  928 col sentences: Agréable
# index:  929 col sentences: Très bien pour 2 ou 3 nuits.
# index:  930 col sentences: Tres bon choix si l'on veut être près de l'Opéra Bastille.
# index:  931 col sentences: Très bien
# index:  932 col sentences: bon accueil, bon rapport qualité/prix
# index:  933 col sentences: Très bien
# index:  934 col sentences: Agréable
# index:  935 col sentences: Bien
# index:  936 col sentences: Pour une nuit de 23h à 7h, c'est pour moi bien suffisant !
# index:  937 col sentences: Bien
# index:  938 col sentences: bien passé
# index:  939 col sentences: Bien
# index:  940 col sentences: Très bien
# index:  941 col sentences: Agréable
# index:  942 col sentences: Pratique pour passer 1 ou 2 nuits
# index:  943 col sentences: Très bien
# index:  944 col sentences: Très bien
# index:  945 col sentences: Agréable
# index:  946 col sentences: Idéalement situé ! J'y retournerai sans hésiter.
# index:  947 col sentences: Très bon rapport qualité prix. Cet hôtel se trouve dans un quartier où tout est à proximité.
# index:  948 col sentences: Bien
# index:  949 col sentences: Bien
# index:  950 col sentences: Très bien
# index:  951 col sentences: bon rapport qualité prix, hotel correct et bon accueil.
# index:  952 col sentences: Bon dépannage pour une nuit.
# index:  953 col sentences: spartiate mais confortable tout de même ,juste le nécessaire pour passer la nuit en plein paris
# index:  954 col sentences: Agréable
# index:  955 col sentences: MAD
# index:  956 col sentences: Très bien
# index:  957 col sentences: Très bien
# index:  958 col sentences: A fuir si vous voulez dormir
# index:  959 col sentences: Séjour correct pour une nuit.
# index:  960 col sentences: Si on n'est pas trop difficile sur le lieu de séjour, cet hôtel peut suffir pour un WE mais en solo
# index:  961 col sentences: Séjour court mais très agréable.
# index:  962 col sentences: Bien
# index:  963 col sentences: Agréable
# index:  964 col sentences: A réfléchir si je retente l'aventure mais nuit agréable
# index:  965 col sentences: Moyen
# index:  966 col sentences: Bien propre et bon service
# index:  967 col sentences: Bien
# index:  968 col sentences: Agréable
# index:  969 col sentences: Le pire hôtel vu.
# index:  970 col sentences: Bien
# index:  971 col sentences: Très bien pour une nuit
# index:  972 col sentences: Bien
# index:  973 col sentences: Simple, assez vétuste mais personnel sympathique et bon rapport qualité prix.
# index:  974 col sentences: Propre et correct
# index:  975 col sentences: Bien
# index:  976 col sentences: Bien
# index:  977 col sentences: Bien
# index:  978 col sentences: Bon
# index:  979 col sentences: Bien
# index:  980 col sentences: Bien
# index:  981 col sentences: Le personnel est agréable mais les locaux trop bruyants
# index:  982 col sentences: Bon
# index:  983 col sentences: Agréable
# index:  984 col sentences: Bien
# index:  985 col sentences: Bien
# index:  986 col sentences: Hôtel économique sans surprise.
# index:  987 col sentences: SÉJOUR CORRECT SANS PLUS
# index:  988 col sentences: Bien
# index:  989 col sentences: Bon séjour à Paris. Dommage pour l’hôtel. Je n'y retournerai pas.
# index:  990 col sentences: Bien
# index:  991 col sentences: Endroit pratique et facile d'accès
# index:  992 col sentences: Bonne adresse
# index:  993 col sentences: Bien
# index:  994 col sentences: Hôtel simple à prix imbattable
# index:  30895 col sentences: Excellent sejour
# index:  30896 col sentences: Magnifico
# index:  30897 col sentences: Exceptionnel
# index:  30898 col sentences: Hotel de rêve et chambre super spacieuse
# index:  30899 col sentences: Service médiocre
# index:  30900 col sentences: Apparthotel interessant pour séjour court familial 4 pers
# index:  30901 col sentences: Excellent
# index:  30902 col sentences: confort et proximité gare Matabiau
# index:  30903 col sentences: Très bien
# index:  30904 col sentences: Magnifique séjour
# index:  30905 col sentences: bien dans l'ensemble
# index:  30906 col sentences: Superbe
# index:  30907 col sentences: Un séjour trop bref !
# index:  30908 col sentences: Super
# index:  30909 col sentences: Très bien
# index:  30910 col sentences: Bien
# index:  30911 col sentences: Bon séjour
# index:  30912 col sentences: Bien
# index:  30913 col sentences: Superbe
# index:  30914 col sentences: Exceptionnel
# index:  30915 col sentences: Exceptionnel
# index:  30916 col sentences: Exceptionnel
# index:  30917 col sentences: Bien
# index:  30918 col sentences: Exceptionnel
# index:  30919 col sentences: Exceptionnel
# index:  30920 col sentences: Exceptionnel
# index:  30921 col sentences: Exceptionnel
# index:  30922 col sentences: Agréable, bien placé mais petit-déj à améliorer
# index:  30923 col sentences: je me suis bien reposé cette nuit là
# index:  30924 col sentences: Bien
# index:  30925 col sentences: Fabuleux
# index:  30926 col sentences: Exceptionnel
# index:  30927 col sentences: Fabuleux
# index:  30928 col sentences: Situation en face de la gare et du centre exceptionnelle
# index:  30929 col sentences: Exceptionnel
# index:  30930 col sentences: Une belle et grande chambre...
# index:  30931 col sentences: Pas à la hauteur pour résidence ****
# index:  30932 col sentences: Bien
# index:  30933 col sentences: Très bien
# index:  30934 col sentences: Près de la gare
# index:  30935 col sentences: Superbe
# index:  30936 col sentences: Exceptionnel
# index:  30937 col sentences: Mon séjours était parfait !
# index:  30938 col sentences: Exceptionnel
# index:  30939 col sentences: Exceptionnel
# index:  30940 col sentences: Superbe
# index:  30941 col sentences: Exceptionnel
# index:  30942 col sentences: Exceptionnel
# index:  30943 col sentences: Hôtel très confortable
# index:  30944 col sentences: Déjà utilisé plusieurs fois
# index:  30945 col sentences: Bien

# %%
#itération sur l'ensemble des lignes du dataframe, affichache de l'index et son commentaire associé
#for index, row in df.iterrows():
    #print('index: ', index, 'col sentences:', row['bons_points'])

# %%
#itération sur l'ensemble des lignes du dataframe, affichache de l'index et son commentaire associé
#for index, row in df.iterrows():
    #print('index: ', index, 'col sentences:', row['bons_points'])

# %%
#str = "ÊÎÔÛÄËÏÖÜÀÆæÇÉÈŒœÙ!!!";
#print(str.lower())

# %%
#def cleaned_data(x):
    #str.lower : mettre tous les éléments en minuscule
    #str.cat : concaténation des strings avec le séparateur donné en paramètre
    #a = x.str.lower().str.cat(sep=' ')
    #print(x)
#df.apply(cleaned_data)

# %%
#columns = list(df.columns)
#print(columns)

# %%
#colum = list(df[column])
#for col in columns : 
    #def[col]=cleaned_data(df[col])
    #str.lower : mettre tous les éléments en minuscule
    #str.cat : concaténation des strings avec le séparateur donné en paramètre
    #a = df[col].str.lower().str.cat(sep=' ')

    #supprimer ponctuation, nombres et retourner une liste de mots
    #b = re.sub('[^a-zàâéèêëïîôùûçæœ]+', ' ', a)

    #supprimer tous les mots "vides" du texte
    #stop_words = list(get_stop_words('french'))         
    #nltk_words = list(stopwords.words('french'))   
    #stop_words.extend(nltk_words)

    #word_tokens = word_tokenize(b)
    #filtered_sentence = [w for w in word_tokens if not w in stop_words]
    #filtered_sentence = []
    #for w in word_tokens:
        #if w not in stop_words:
            #filtered_sentence.append(w)

    #supprimer les mots qui ont une longueur inférieure à 2  
    #without_single_chr = [word for word in filtered_sentence if len(word) > 2]

    #suppression des caractères numériques
    #cleaned_data = [word for word in without_single_chr if not word.isnumeric()]

# %%
#str.lower : mettre tous les éléments en minuscule
#str.cat : concaténation des strings avec le séparateur donné en paramètre
a = df['titre'].str.lower().str.cat(sep=' ')

#supprimer ponctuation, nombres et retourner une liste de mots
b = re.sub('[^a-zàâéèêëïîôùûçæœ]+', ' ', a)

#supprimer tous les mots "vides" du texte
stop_words = list(get_stop_words('french'))         
nltk_words = list(stopwords.words('french'))   
stop_words.extend(nltk_words)

#token = entité (ou unité) lexicale 
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#supprimer les mots qui ont une longueur inférieure à 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

#suppression des caractères numériques
cleaned_data = [word for word in without_single_chr if not word.isnumeric()]

# %%
#calculer les 100 mots les plus fréquents
top_N = 100
word_dist = nltk.FreqDist(cleaned_data)
rslt = pd.DataFrame(word_dist.most_common(top_N), columns=['Word', 'Frequency'])

# %%
#affichage dans un dataframe des 7 mots les plus fréquents
rslt.head(7)
# Out:
#            Word  Frequency
# 0          bien       9543
# 1      agréable       3078
# 2        séjour       2600
# 3  exceptionnel       2237
# 4      fabuleux       1635
# 5         hôtel       1506
# 6          prix       1223

# %%
#histogramme des 7 mots les plus fréquents
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
#nuage de mots
wcloud(cleaned_data,'black','Common Words')

# %%
#mettre tous les éléments en miniscule, séparés par un espace
a = df['bons_points'].str.lower().str.cat(sep=' ')

#supprimer ponctuation, nombres and retourner une liste de mots
b = re.sub('[^a-zàâéèêëïîôùûç]+', ' ', a)

#supprimer tous les mots "vides" du texte
stop_words = list(get_stop_words('french'))         
nltk_words = list(stopwords.words('french'))   
stop_words.extend(nltk_words)

word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#supprimer les mots qui ont une longueur inférieure à 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# %%
#supprimer les caractères numériques
cleaned_data = [word for word in without_single_chr if not word.isnumeric()]        

#calculer les 100 mots les plus fréquents
top_N = 100
word_dist = nltk.FreqDist(cleaned_data)
rslt = pd.DataFrame(word_dist.most_common(top_N), columns=['Word', 'Frequency'])

# %%
#affichage dans un dataframe des 7 mots les plus fréquents
rslt.head(7)
# Out:
#           Word  Frequency
# 0    personnel       7096
# 1        petit       6657
# 2      chambre       6587
# 3     déjeuner       5299
# 4         bien       5126
# 5      accueil       4875
# 6  emplacement       4508

# %%
#histogramme des 7 mots les plus fréquents
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
#nuage de mots
wcloud(cleaned_data,'black','Common Words')

# %%
#mettre tous les éléments en miniscule, séparés par un espace
a = df['mauvais_points'].str.lower().str.cat(sep=' ')

#supprimer ponctuation, nombres and retourner une liste de mots
b = re.sub('[^A-Za-zàâéèêëïîôùûç]+', ' ', a)

#supprimer tous les mots "vides" du texte
stop_words = list(get_stop_words('french'))         
nltk_words = list(stopwords.words('french'))   
stop_words.extend(nltk_words)

word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#supprimer les mots qui ont une longueur inférieure à 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

#supprimer caractères numériques
cleaned_data = [word for word in without_single_chr if not word.isnumeric()]

# %%
#supprimer caractères numériques
cleaned_data = [word for word in without_single_chr if not word.isnumeric()]        

#calculer les 100 mots les plus fréquents
top_N = 100
word_dist = nltk.FreqDist(cleaned_data)
rslt = pd.DataFrame(word_dist.most_common(top_N), columns=['Word', 'Frequency'])

# %%
#affichage dans un dataframe des 7 mots les plus fréquents
rslt.head(7)
# Out:
#        Word  Frequency
# 0   chambre       6337
# 1     petit       3380
# 2     salle       3138
# 3  déjeuner       2309
# 4      bain       2243
# 5    douche       2047
# 6      rien       1998

# %%
#histogramme des 7 mots les plus fréquents
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
#nuage de mots
wcloud(cleaned_data,'black','Common Words')

# %%
#vérification que les NaN dans la colonne 'mauvais points' ont bien de façon certaine une polarité de zéro pour TextBlob, 
#sentiment[0]=polarite et sentiment[1]=subjectivité
#text = u"NaN"
#blob = TextBlob(text, pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
#blob.sentiment
#print('NaN a une polarité de {} et une subjectivité de {}.'.format(blob.sentiment[0], blob.sentiment[1]))

# %%
#suppression des Nan
#df = df.fillna('')
#suppression de deux phrases récurrentes dans les données
#df = df[df.bons_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
#df = df[df.bons_points != "Ce client n'a pas laissé de commentaire."]

#df = df[df.mauvais_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
#df = df[df.mauvais_points != "Ce client n'a pas laissé de commentaire."]

# %%
#suppression de deux phrases récurrentes dans les données
#df = df[df.bons_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
#df = df[df.bons_points != "Ce client n'a pas laissé de commentaire."]

#df = df[df.mauvais_points != "Ce commentaire n'apparaît pas car il ne respecte pas notre charte."]
#df = df[df.mauvais_points != "Ce client n'a pas laissé de commentaire."]

# %%
#concaténation 
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
df22 = pd.DataFrame(df, columns= ['bons_points', 'mauvais_points'])

df23=df22['bons_points']
df24=df22['mauvais_points']

# %%
df23=pd.DataFrame(data=df23)
#df23['polarite']=1
df23.head()
# Out:
#                                          bons_points
# 0  Établissement recent, propre, soigne, chouette...
# 1  Accueil très chaleureux, chambre calme...tout ...
# 2  Tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  Excellent rapport qualité prix. Personnel très...

# %%
df24=pd.DataFrame(data=df24)
#df24['polarité']=0
df24.columns = ['bons_points']
df24.head()
# Out:
#                       bons_points
# 0                            Rien
# 1
# 2
# 3  Hôtel parfait. Quartier sympa.
# 4

# %%
frames = [df23, df24]
result = pd.concat(frames)
result
# Out:
#                                              bons_points
# 0      Établissement recent, propre, soigne, chouette...
# 1      Accueil très chaleureux, chambre calme...tout ...
# 2      Tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4      Excellent rapport qualité prix. Personnel très...
# ...                                                  ...
# 30941  C'est regrettable de ne pas avoir de plateau d...
# 30942                     Rien tout étais au top! Merci!
# 30943                                               Rien
# 30944
# 30945                                           Le bruit
#
# [58844 rows x 1 columns]

# %%
df21 = result['bons_points']
df21 = pd.DataFrame(df21, columns=['bons_points'])

# %%
df21.columns=['sentences']

# %%
df21.head()
# Out:
#                                            sentences
# 0  Établissement recent, propre, soigne, chouette...
# 1  Accueil très chaleureux, chambre calme...tout ...
# 2  Tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  Excellent rapport qualité prix. Personnel très...

# %%
df25 = result['bons_points']
df25 = pd.DataFrame(df25, columns=['bons_points'])

# %%
df25.head()
# Out:
#                                          bons_points
# 0  Établissement recent, propre, soigne, chouette...
# 1  Accueil très chaleureux, chambre calme...tout ...
# 2  Tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  Excellent rapport qualité prix. Personnel très...

# %%
df25.columns=['sentence']

# %%
#df25['sentences'] = df25['sentences'].apply(lambda x: re.sub('[^a-zàâéèêëïîôùûçæœ]+',' ', str(x)))

# %%
#df25['sentences']=df25.sentences.str.replace(r'\b(\w{1,2})\b', '')

# %%
#stop = stopwords.words('french')
#df25['sentences'].apply(lambda x: [item for item in x if item not in stop])

# %%
df25.head()
# Out:
#                                             sentence
# 0  Établissement recent, propre, soigne, chouette...
# 1  Accueil très chaleureux, chambre calme...tout ...
# 2  Tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  Excellent rapport qualité prix. Personnel très...

# %%
#mettre les commentaires du dataframe en miniscule
df25['sentence']=df25['sentence'].str.lower()
df25.head()
# Out:
#                                             sentence
# 0  établissement recent, propre, soigne, chouette...
# 1  accueil très chaleureux, chambre calme...tout ...
# 2  tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  excellent rapport qualité prix. personnel très...

# %%
df25['sentence'] = df25['sentence'].apply(lambda x: re.sub('[^a-zàâéèêëïîôùûçæœ]+',' ', str(x)))

# %%
df25['sentence']=df25.sentence.str.replace(r'\b(\w{1,2})\b', '')

# %%
def identify_tokens(row):
    review = row['sentence']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    #token_words = [w for w in tokens if w.isalpha()]
    return tokens

df25['sentence'] = df25.apply(identify_tokens, axis=1)

# %%
stop = stopwords.words('french')
df25['sentence'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# 0        [établissement, recent, propre, soigne, chouet...
# 1        [accueil, très, chaleureux, chambre, calme, to...
# 2        [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                       []
# 4        [excellent, rapport, qualité, prix, personnel,...
#                                ...
# 30941    [regrettable, avoir, plateau, courtoisie, cham...
# 30942                             [rien, tout, top, merci]
# 30943                                               [rien]
# 30944                                                   []
# 30945                                              [bruit]
# Name: sentence, Length: 58844, dtype: object

# %%
df25.head()
# Out:
#                                             sentence
# 0  [établissement, recent, propre, soigne, chouet...
# 1  [accueil, très, chaleureux, chambre, calme, to...
# 2  [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                 []
# 4  [excellent, rapport, qualité, prix, personnel,...

# %%
df25.shape
# Out:
# (58844, 1)

# %%
df21.columns=['sentences']

# %%
#mettre les commentaires du dataframe en miniscule
df21['sentences']=df21['sentences'].str.lower()
df21.head()
# Out:
#                                            sentences
# 0  établissement recent, propre, soigne, chouette...
# 1  accueil très chaleureux, chambre calme...tout ...
# 2  tout bié sauf le wifi catastrophiquement lent!...
# 3
# 4  excellent rapport qualité prix. personnel très...

# %%
df21['sentences'] = df21['sentences'].apply(lambda x: re.sub('[^a-zàâéèêëïîôùûçæœ]+',' ', str(x)))

# %%
df21['sentences']=df21.sentences.str.replace(r'\b(\w{1,2})\b', '')

# %%
def identify_tokens(row):
    review = row['sentences']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    #token_words = [w for w in tokens if w.isalpha()]
    return tokens

df21['sentences'] = df21.apply(identify_tokens, axis=1)

# %%
stop = stopwords.words('french')
df21['sentences'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# 0        [établissement, recent, propre, soigne, chouet...
# 1        [accueil, très, chaleureux, chambre, calme, to...
# 2        [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                       []
# 4        [excellent, rapport, qualité, prix, personnel,...
#                                ...
# 30941    [regrettable, avoir, plateau, courtoisie, cham...
# 30942                             [rien, tout, top, merci]
# 30943                                               [rien]
# 30944                                                   []
# 30945                                              [bruit]
# Name: sentences, Length: 58844, dtype: object

# %%
df21.head()
# Out:
#                                            sentences
# 0  [établissement, recent, propre, soigne, chouet...
# 1  [accueil, très, chaleureux, chambre, calme, to...
# 2  [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                 []
# 4  [excellent, rapport, qualité, prix, personnel,...

# %%
#récupération des commentaires dans le type series
df22 = df21['sentences']
type(df22)
# Out:
# pandas.core.series.Series

# %%
#récupération des commentaires dans le type series
#df21 = df21['sentences']
#type(df21)

# %%
#calcul de la polarité des commentaires avec TextBlob
bloblist_desc = list()

df_str=df22.astype(str)
for row in df_str:
    blob = TextBlob(row)
    #print(blob)
    pos_tagger=PatternTagger()
    analyzer=PatternAnalyzer()
    blob = tb(str(blob)) #textblob
    #sentiment renvoie un tuple avec la polarité et la subjectivite
    #print(blob.sentiment[0])
    #type(blob.sentiment[0])
    bloblist_desc.append(blob.sentiment[0])
    #df_polarity_desc1 = pd.DataFrame(bloblist_desc, columns = ['sentiment'])

# %%
#récupération des résultats de la polarité dans un dataframe
df_polarity_desc1 = pd.DataFrame(data = bloblist_desc)
df_polarity_desc1.columns = ['sentiment']
df_polarity_desc1.head()
# Out:
#    sentiment
# 0   0.261429
# 1   0.422500
# 2  -0.066667
# 3   0.000000
# 4   0.487500

# %%
#classification des commentaires selon trois modalités (neutres, positifs et négatifs) dans un dataframe
def f(df_polarity_desc1):
    if df_polarity_desc1['sentiment'] > 0:
        val = "positive"
    elif df_polarity_desc1['sentiment'] < 0:
        val = "negative"
    else :
        val = "neutre"
    return val

df_polarity_desc1.apply(f, axis=1)
df_polarity_desc1['polarite']=df_polarity_desc1.apply(f, axis=1)

# %%
df_polarity_desc1.head()
# Out:
#    sentiment  polarite
# 0   0.261429  positive
# 1   0.422500  positive
# 2  -0.066667  negative
# 3   0.000000    neutre
# 4   0.487500  positive

# %%
#fonction de masse de la polarité des commentaires
num_bins = 50
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(df_polarity_desc1.sentiment, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of polarity')
plt.show();

# %%
#boxenplot de la polarité des commenatires, boxplot avec plus de quartiles
plt.figure(figsize=(10,6))
sns.boxenplot(x='polarite', y='sentiment', data=df_polarity_desc1)
plt.show();

# %%
#countplot des modalités correspondant à la polarité des commentaires
df_polarity_desc1.head()
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.countplot(x="polarite", data=df_polarity_desc1)

# %%
#diagramme circulaire des modalités de la polarité des commentaires
pourcentage_positive = round(len(df_polarity_desc1.loc[(df_polarity_desc1.polarite == "positive")])) / len(df_polarity_desc1)
pourcentage_negative = round(len(df_polarity_desc1.loc[(df_polarity_desc1.polarite == "negative")])) / len(df_polarity_desc1)
pourcentage_neutre = round(len(df_polarity_desc1.loc[(df_polarity_desc1.polarite == "neutre")])) / len(df_polarity_desc1)

fig1, ax1 = plt.subplots()

plt.title("Pourcentage des commentaires positifs vs négatifs vs neutres", fontsize=18)
labels = ['positif', 'négatif', 'neutre']
sizes = [pourcentage_positive, pourcentage_negative, pourcentage_neutre]
#explode = (0, 0.2)  # seulement détacher le second groupe

patches, texts, autotexts = ax1.pie(sizes,  labels=labels, autopct='%1.1f%%', shadow = True, startangle=130, colors = ['#00e64d', 'r', '#FFD700'])
texts[0].set_fontsize(15)
texts[1].set_fontsize(15)
texts[2].set_fontsize(15)

matplotlib.rcParams['text.color'] = 'black'
matplotlib.rcParams["font.size"] = 18
plt.rcParams["figure.figsize"] = [6, 6]

# %%
df = pd.read_csv(r"C:\Users\utilisateur\Documents\Projet\ProjetNLP\booking.csv", na_values=['None'], decimal=',')
df23=df['note']
df24=df['note']
frames = [df23, df24]
df_notes = pd.concat(frames)
df_notes.shape
# Out:
# (61892,)

# %%
type(df_notes)
# Out:
# pandas.core.series.Series

# %%
df_polarity_desc1_polarite = df_polarity_desc1.iloc[:,1]
#df_polarity_desc1_polarite = pd.DataFrame(df_polarity_desc1_polarite)
df_polarity_desc1_polarite.head()
# Out:
# 0    positive
# 1    positive
# 2    negative
# 3      neutre
# 4    positive
# Name: polarite, dtype: object

# %%
df_notes.reset_index(drop=True, inplace=True)
df_polarity_desc1_polarite.reset_index(drop=True, inplace=True)
df_corr = pd.concat([df_polarity_desc1_polarite, df_notes], axis = 1)

# %%
df_corr.head()
# Out:
#    polarite  note
# 0  positive  10.0
# 1  positive   9.0
# 2  negative   9.6
# 3    neutre  10.0
# 4  positive   9.0

# %%
df_corr=df_corr.loc[(df_corr.polarite=='positive')|(df_corr.polarite=='negative')]

# %%
type(df_corr)
# Out:
# pandas.core.frame.DataFrame

# %%
df_corr.head()
# Out:
#    polarite  note
# 0  positive  10.0
# 1  positive   9.0
# 2  negative   9.6
# 4  positive   9.0
# 5  positive   7.9

# %%
df_corr['polarite'] = np.where(df_corr['polarite'] == 'positive', 1, 0)
df_corr.head()
# Out:
#    polarite  note
# 0         1  10.0
# 1         1   9.0
# 2         0   9.6
# 4         1   9.0
# 5         1   7.9

# %%
#affichage des corrélations entre variables
#parfaite si r = 1
#très forte si r > 0,8
#forte si r se situe entre 0,5 et 0,8
#d'intensité moyenne si r se situe entre 0,2 et 0,5
#faible si r se situe entre 0 et 0.2

f, ax = plt.subplots(figsize=(12, 12))
plt.title('Correlation entre variables')
sns.heatmap(df_corr.corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black', annot=True);

# %%
#concaténation des trois colonnes correspondant aux commentaires sur les hôtels
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
df22 = pd.DataFrame(df, columns= ['titre', 'bons_points', 'mauvais_points'])

df20 = df['titre'].map(str) + ' ' + df['bons_points'].map(str) + ' ' + df['mauvais_points'].map(str)

df20
# Out:
# 0        Exceptionnel Établissement recent, propre, soi...
# 1        Fabuleux  Accueil très chaleureux, chambre cal...
# 2        Exceptionnel Tout bié sauf le wifi catastrophi...
# 3          Exceptionnel nan Hôtel parfait. Quartier sympa.
# 4        Fabuleux  Excellent rapport qualité prix. Pers...
#                                ...
# 30941    Exceptionnel L'hôtel est agréable et confortab...
# 30942    Exceptionnel La chambre, le personnel au top e...
# 30943    Hôtel très confortable La chambre, ses équipem...
# 30944         Déjà utilisé plusieurs fois Salle claire nan
# 30945           Bien  La situation face à la gare Le bruit
# Length: 30946, dtype: object

# %%
#convertir series en dataframe
df20 = df20.to_frame(name="sentences")

# %%
#mettre les commentaires du dataframe en miniscule
df20['sentences']=df20['sentences'].str.lower()
df20.head()
# Out:
#                                            sentences
# 0  exceptionnel établissement recent, propre, soi...
# 1  fabuleux  accueil très chaleureux, chambre cal...
# 2  exceptionnel tout bié sauf le wifi catastrophi...
# 3    exceptionnel nan hôtel parfait. quartier sympa.
# 4  fabuleux  excellent rapport qualité prix. pers...

# %%
#remplacement de tout ce qui n'est pas dans le set[] par un espace
df20['sentences'] = df20['sentences'].apply(lambda x: re.sub('[^a-zàâéèêëïîôùûçæœ-]+',' ', str(x))) 
#for index, row in df21.iterrows():
    #print('index: ', index, 'col sentences:', row['sentences'])

# %%
#suppression des mots "vides" dans le dataframe
stop = stopwords.words('french')
df20['sentences'] = df20['sentences'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
#for index, row in df21.iterrows():
    #print('index: ', index, 'col sentences:', row['sentences'])

# %%
#suppression des mots d'une longueur inférieure à 2 caractères
#\b=la fin et le début d'un mot
#`r' ou`R': préfixe pour les chaines de caractère 
df20['sentences']=df20.sentences.str.replace(r'\b(\w{1,2})\b', '')
#for index, row in df21.iterrows():
    #print('index: ', index, 'col sentences:', row['sentences'])

# %%
df20=df20.copy()

# %%
type(df20)
# Out:
# pandas.core.frame.DataFrame

# %%
df20.head()
# Out:
#                                            sentences
# 0  exceptionnel établissement recent propre soign...
# 1  fabuleux accueil très chaleureux chambre calme...
# 2  exceptionnel tout bié sauf wifi catastrophique...
# 3      exceptionnel nan hôtel parfait quartier sympa
# 4  fabuleux excellent rapport qualité prix person...

# %%
#Existe-t-il des variables numériques?
df20['sentences'].apply(lambda x: not any(i.isnumeric() for i in x.split())).any()
# Out:
# False

# %%
#récupération des commentaires dans le type series
df20 = df20['sentences']
type(df20)
# Out:
# pandas.core.series.Series

# %%
#calcul de la polarité des commentaires avec TextBlob
bloblist_desc = list()

df_str=df20.astype(str)
for row in df_str:
    blob = TextBlob(row)
    #print(blob)
    pos_tagger=PatternTagger()
    analyzer=PatternAnalyzer()
    blob = tb(str(blob)) #textblob
    #sentiment renvoie un tuple avec la polarité et la subjectivite
    #print(blob.sentiment[0])
    #type(blob.sentiment[0])
    bloblist_desc.append(blob.sentiment[0])
    #df_polarity_desc1 = pd.DataFrame(bloblist_desc, columns = ['sentiment'])

# %%
#récupération des résultats de la polarité dans un dataframe
df_polarity_desc1 = pd.DataFrame(data = bloblist_desc)
df_polarity_desc1.columns = ['sentiment']
df_polarity_desc1.head()
# Out:
#       sentiment
# 0  2.537500e-01
# 1  5.380000e-01
# 2  1.387779e-17
# 3  4.000000e-01
# 4  5.900000e-01

# %%
#classification des commentaires selon trois modalités (neutres, positifs et négatifs) dans un dataframe
def f(df_polarity_desc1):
    if df_polarity_desc1['sentiment'] > 0:
        val = "positive"
    elif df_polarity_desc1['sentiment'] < 0:
        val = "negative"
    else :
        val = "neutre"
    return val

df_polarity_desc1.apply(f, axis=1)
df_polarity_desc1['polarite']=df_polarity_desc1.apply(f, axis=1)

# %%
#sélection de la colonne notes 
df = pd.read_csv(r"C:\Users\utilisateur\Documents\Projet\ProjetNLP\booking.csv", na_values=['None'], decimal=',')
df_notes = df.iloc[:,7]
#df_notes = pd.DataFrame(data=df_notes)
df_notes.head()
# Out:
# 0    10.0
# 1     9.0
# 2     9.6
# 3    10.0
# 4     9.0
# Name: note, dtype: float64

# %%
#sélection de la colonne polarite
df_polarity_desc1_polarite = df_polarity_desc1.iloc[:,1]
#df_polarity_desc1_polarite = pd.DataFrame(df_polarity_desc1_polarite)
df_polarity_desc1_polarite.head()
# Out:
# 0    positive
# 1    positive
# 2    positive
# 3    positive
# 4    positive
# Name: polarite, dtype: object

# %%
#concaténation de la colonne notes et polarite
df_corr = pd.concat([df_polarity_desc1_polarite, df_notes], axis = 1)

# %%
#sélection des modalités postives ou négatives
df_corr=df_corr.loc[(df_corr.polarite=='positive')|(df_corr.polarite=='negative')]

# %%
#transformation des valeurs de la polarite en code binaire 0 et 1
df_corr['polarite'] = np.where(df_corr['polarite'] == 'positive', 1, 0)
df_corr.head()
# Out:
#    polarite  note
# 0         1  10.0
# 1         1   9.0
# 2         1   9.6
# 3         1  10.0
# 4         1   9.0

# %%
#affichage des corrélations entre variables
#parfaite si r = 1
#très forte si r > 0,8
#forte si r se situe entre 0,5 et 0,8
#d'intensité moyenne si r se situe entre 0,2 et 0,5
#faible si r se situe entre 0 et 0.2

f, ax = plt.subplots(figsize=(12, 12))
plt.title('Correlation entre variables')
sns.heatmap(df_corr.corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black', annot=True);

# %%
#df_polarity_desc1.head()

# %%
#df_polarity_desc1.columns

# %%
#Transformation des valeurs de la variable polarite en 1 et 0
#pas besoin d'utiliser le module scikit-learn car on peut le faire directement 
df_polarity_desc1['polarite'] = np.where(df_polarity_desc1['polarite'] == 'positive', 1, 0)
df_polarity_desc1 = df_polarity_desc1.reset_index(drop=True)
df_polarity_desc1.head()
# Out:
#       sentiment  polarite
# 0  2.537500e-01         1
# 1  5.380000e-01         1
# 2  1.387779e-17         1
# 3  4.000000e-01         1
# 4  5.900000e-01         1

# %%
#supression de la colonne sentiment
df_polarity_desc1.drop(['sentiment'],1,inplace=True)
df_polarity_desc1.head()
# Out:
#    polarite
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
df25.head()
# Out:
#                                             sentence
# 0  [établissement, recent, propre, soigne, chouet...
# 1  [accueil, très, chaleureux, chambre, calme, to...
# 2  [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                 []
# 4  [excellent, rapport, qualité, prix, personnel,...

# %%
df25['sentiment']=df_polarity_desc1['polarite']

# %%
df25.head()
# Out:
#                                             sentence  sentiment
# 0  [établissement, recent, propre, soigne, chouet...          1
# 1  [accueil, très, chaleureux, chambre, calme, to...          1
# 2  [tout, bié, sauf, wifi, catastrophiquement, le...          1
# 3                                                 []          1
# 4  [excellent, rapport, qualité, prix, personnel,...          1

# %%
lemmatizer = FrenchLefffLemmatizer()
def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return lem_text

# %%
lemmatizer.lemmatize('avions')
# Out:
# 'avion'

# %%
df25['sentence'].apply(lambda x : word_lemmatizer(x))
# Out:
# 0        [établissement, recent, propre, soigne, chouet...
# 1        [accueil, très, chaleureux, chambre, calme, to...
# 2        [tout, bié, sauf, wifi, catastrophiquement, le...
# 3                                                       []
# 4        [excellent, rapport, qualité, prix, personnel,...
#                                ...
# 30941    [est, regrettable, pas, avoir, plateau, courto...
# 30942                       [rien, tout, étai, top, merci]
# 30943                                               [rien]
# 30944                                                   []
# 30945                                              [bruit]
# Name: sentence, Length: 58844, dtype: object

# %%
import pandas as pd
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("french")
df25['sentence'] = df25['sentence'].apply(lambda x: [stemmer.stem(y) for y in x])

# %%
df25.head()
# Out:
#                                             sentence  sentiment
# 0  [établ, recent, propr, soign, chouet, design, ...          1
# 1  [accueil, tres, chaleur, chambr, calm, tout, p...          1
# 2  [tout, bi, sauf, wif, catastroph, lent, meg, p...          1
# 3                                                 []          1
# 4  [excellent, rapport, qualit, prix, personnel, ...          1

# %%
df25.shape
# Out:
# (58844, 2)

# %%
#supression des données manquantes
df.isnull().values.any()
df.isnull().sum()
df=df.dropna()

# %%
#vérification des données manquantes
df.isnull().sum()
# Out:
# nom                   0
# pays                  0
# favorite              0
# date                  0
# titre                 0
# bons_points           0
# mauvais_points        0
# note                  0
# type_etablissement    0
# lieu                  0
# note_etablissement    0
# dtype: int64

# %%
#création d'un csv contenant le dataframe df utilisé pour le machine learning
#df25.to_csv('DatasetMarchineLearning.csv', index=True)

# %% [markdown]
# <h1>3. Machine learning</h1>

# %%
#création jeux train et test
X_train, X_test, y_train, y_test = train_test_split(df25[['sentence']], df25['sentiment'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-9fad92c821fc> in <module>
#       1 #création jeux train et test
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(df[['sentence']], df['sentiment'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['sentence'], dtype='object')] are in the [columns]"

# %%
"""CountVectorizer de Scikit-learn est utilisé pour transformer un corpus de mots en 
vecteurs/occurence des mots """
#Tf signifie term-frequency tandis que tfidf signifie inverse document-frequency
#IDF(word) = Log((Total number of documents)/(Number of documents containing the word))
pipe = make_pipeline(CountVectorizer(), TfidfTransformer())
pipe.fit(X_train['sentence'])
feat_train = pipe.transform(X_train['sentence'])
feat_train.shape

# %%
#minimum et maximum pour feat_train
feat_train.min(), feat_train.max()

# %%
#transformer sans entrainer sur notre jeu test
feat_test = pipe.transform(X_test['sentence'])
feat_test.shape

# %%
#arbre de décision
#définir les paramètres
#le paramètre max_depth est un seuil sur la profondeur maximale de l’arbre
"""L'indice de diversité de gini : probabilité pour chaque élément d'être choisi multipliée 
par la probabilité qu'il soit mal classé"""
"""L'entropie au lieu d'utiliser les probabilités simples applique le log2 des probabilités"""
param_grid = {'max_depth' : [400, 500], 
              'criterion' : ['gini', 'entropy']}
             
dtc = DecisionTreeClassifier(random_state=42)

dtc_grid = GridSearchCV(dtc, param_grid, cv=3)
 
#entrainer le modèle à partir de Grid Search
# %time DTC = dtc_grid.fit(feat_train, y_train)

print(dtc_grid.best_score_.round(5))
print(dtc_grid.best_params_)

final_model = dtc_grid.best_estimator_

pred_train = final_model.predict(feat_train) 
pred_test = final_model.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
def MatriceConfusion(model):
    y_pred = model.predict(feat_test)
    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, pred_test)
    plt.matshow(cm)
    plt.title('Matrice de confusion', y=1.12)
    plt.colorbar()
    print(cm)
    plt.show()

# %%
y_prediction = MatriceConfusion(DTC)

# %%
score = final_model.predict_proba(feat_test)
fpr, tpr, th = roc_curve(y_test, score[:, 1])
fig, ax = plt.subplots(1, 1, figsize=(4,4))
ax.plot([0, 1], [0, 1], 'k--')
aucf = auc(fpr, tpr)
ax.plot(fpr, tpr, label='auc=%1.5f' % aucf)
ax.set_title('Courbe ROC - classifieur de sentiments')
ax.legend();

# %%
"""n_estimators = le nombre d'arbres dans la fôrét"""
"""Le Bootstrapping est un procédé qui permet d’augmenter artificiellement le nombre d’observation d’un 
échantillon de données sans pour autant modifier la distribution des variables présentes dans le jeu de 
données. Le principe est simple, on dispose d’un jeu de données contenant n observations, pour créer un 
échantillon de taille n  on tire avec remise n observations parmi le jeu de données original"""
param_grid = {'max_depth' : [30, 50],
             'n_estimators' : [150, 200]}
              #'bootstrap' : [True, False],
              #'criterion' : ['gini','entropy'] 

rfc = RandomForestClassifier(random_state=42)

rfc_grid = GridSearchCV(rfc, param_grid, cv = 3)

# %time RFC = rfc_grid.fit(feat_train, y_train)

print(rfc_grid.best_score_.round(5))
print(rfc_grid.best_params_)

final_model = rfc_grid.best_estimator_

pred_train = final_model.predict(feat_train) 
pred_test = final_model.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
y_pred = MatriceConfusion(RFC)

# %%
score = final_model.predict_proba(feat_test)
fpr, tpr, th = roc_curve(y_test, score[:, 1])
fig, ax = plt.subplots(1, 1, figsize=(4,4))
ax.plot([0, 1], [0, 1], 'k--')
aucf = auc(fpr, tpr)
ax.plot(fpr, tpr, label='auc=%1.5f' % aucf)
ax.set_title('Courbe ROC - classifieur de sentiments')
ax.legend();

# %%
"""L1 : Lasso et L2 : Ridge, pénalité, c’est une modification qu’on apporte à la fonction de coût 
afin de maîtriser l’arbitrage entre biais vs variance"""
"""la fonction de coût est définie comme le carré de la différence entre la valeur prévue et la 
valeur réelle en fonction de l'intrant"""
"""quand le biais augmente, la variance baisse"""
param_grid = {'penalty' : ['l1', 'l2']}

lr = LogisticRegression(random_state=42)

lr_grid = GridSearchCV(lr, param_grid, cv = 3)

# %time LR = lr_grid.fit(feat_train, y_train)

print(lr_grid.best_score_.round(5))
print(lr_grid.best_params_)

final_model = lr_grid.best_estimator_

pred_train = final_model.predict(feat_train) 
pred_test = final_model.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
y_pred = MatriceConfusion(LR)

# %%
y_score = final_model.decision_function(feat_test)

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
#bagging
"""Le mot Bagging est une contraction de Bootstrap Aggregation : sélection de sous-ensembles aléatoires de
l'ensemble des données d'origine, puis agrégation des prédictions individuelles pour former une prédiction
finale""" 

naivebayes = nb.BernoulliNB()
modelB = BC(base_estimator = naivebayes, n_estimators = 1000, warm_start = True, bootstrap_features=True, max_samples=0.9)
modelB_fit = modelB.fit(feat_train, y_train)
modelB_fit.score(feat_test,y_test)
pred_train = modelB.predict(feat_train)
pred_test = modelB.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
y_pred = MatriceConfusion(modelB_fit)

# %%
score = modelB_fit.predict_proba(feat_test)
fpr, tpr, th = roc_curve(y_test, score[:, 1])
fig, ax = plt.subplots(1, 1, figsize=(4,4))
ax.plot([0, 1], [0, 1], 'k--')
aucf = auc(fpr, tpr)
ax.plot(fpr, tpr, label='auc=%1.5f' % aucf)
ax.set_title('Courbe ROC - classifieur de sentiments')
ax.legend();

# %%
param_grid = {#'C': [10, 50, 100,200],
              #'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf','sigmoid']}

svm = SVC(random_state=42)

svm_grid = GridSearchCV(svm, param_grid, cv=3)

# %time SVM = svm_grid.fit(feat_train, y_train)

print(svm_grid.best_score_.round(5))
print(svm_grid.best_params_)

# %%
final_model = svm_grid.best_estimator_

# %%
pred_train = final_model.predict(feat_train) 
pred_test = final_model.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
y_pred = MatriceConfusion(SVM)

# %%
y_score = SVM.decision_function(feat_test)

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
param_grid = {
    #"learning_rate": [0.05,0.01, 0.1],
    #"max_depth":[20, 30, 50],
    #"criterion": ["friedman_mse", "mae", "mse"],
    'n_estimators' : [30, 50, 70]}

gbc=GradientBoostingClassifier(random_state=42)

gbc_grid = GridSearchCV(gbc, param_grid, cv = 3)

# %time GBC = gbc_grid.fit(feat_train, y_train)
print (gbc_grid.best_score_.round(5))
print(gbc_grid.best_params_)

final_model = gbc_grid.best_estimator_

pred_train = final_model.predict(feat_train) 
pred_test = final_model.predict(feat_test)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
y_pred = MatriceConfusion(GBC)

# %%
score = gbc_grid.predict_proba(feat_test)
fpr, tpr, th = roc_curve(y_test, score[:, 1])
fig, ax = plt.subplots(1, 1, figsize=(4,4))
ax.plot([0, 1], [0, 1], 'k--')
aucf = auc(fpr, tpr)
ax.plot(fpr, tpr, label='auc=%1.5f' % aucf)
ax.set_title('Courbe ROC - classifieur de sentiments')
ax.legend();

# %%
#un n-gramme est “une sous-séquence de n éléments construite à partir d’une séquence donnée” 
#n-gramme permet de créer un modèle probabiliste pour anticiper le prochain élément d’une suite
#padding="remplissage"
generated_ngrams = ngrams(word_tokenize(X_train.iloc[0,0]), 3, pad_left=True, pad_right=True)
list(generated_ngrams)[:7]

# %%
#ngram_range of (1, 2) means unigrams and bigrams
#Un 2-gram (or bi-gram) est une séquance de 2 mots : “please turn”, “turn your” 
pipe2 = make_pipeline(CountVectorizer(ngram_range=(1, 2)),
                      TfidfTransformer())
pipe2.fit(X_train['sentence'])
feat_train2 = pipe2.transform(X_train['sentence'])
feat_train2.shape

# %%
#get_feature_names() - retourne une liste de feature names, classés par leurs indices
cl = pipe2.steps[0]
cl[1].get_feature_names()[:10]

# %%
feat_test2 = pipe2.transform(X_test['sentence'])

# %%
param_grid = {'penalty' : ['l1', 'l2']}

lr = LogisticRegression(random_state=42)

lr_grid = GridSearchCV(lr, param_grid, cv = 3)

# %time LR = lr_grid.fit(feat_train2, y_train)

print(lr_grid.best_score_.round(5))
print(lr_grid.best_params_)

# %%
feat_test2 = pipe2.transform(X_test['sentence'])

# %%
final_model = lr_grid.best_estimator_

pred_train = final_model.predict(feat_train2) 
pred_test = final_model.predict(feat_test2)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_train, pred_train))

# %%
"""SVD est une technique de factorisation matricielle qui factorise une matrice M dans les trois matrices U,
Σ  et V. Très similaire à l'ACP, sauf que la factorisation pour SVD est effectuée sur la matrice de données, tandis que pour PCA, est une technique de factorisation matricielle qui factorise une matrice M dans les trois matrices U, Σ et V.Ceci est très similaire à l'ACP, sauf que la factorisation pour SVD est effectuée sur la matrice de données, 
pas sur la matrice de covariance."""
#n_components, dimensions qui doivent être inférieures aux colonnes
pipe_svd = make_pipeline(CountVectorizer(), TruncatedSVD(n_components=300))
pipe_svd.fit(X_train['sentence'])
feat_train_svd = pipe_svd.transform(X_train['sentence'])
feat_train_svd.shape

# %%
param_grid = {'penalty' : ['l1', 'l2']}

lr = LogisticRegression(random_state=42)

lr_grid = GridSearchCV(lr, param_grid, cv = 3)

# %time LR = lr_grid.fit(feat_train_svd, y_train)

print(lr_grid.best_score_.round(5))
print(lr_grid.best_params_)

# %%
feat_test_svd = pipe_svd.transform(X_test['sentence'])

# %%
final_model = lr_grid.best_estimator_

pred_train = final_model.predict(feat_train_svd) 
pred_test = final_model.predict(feat_test_svd)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
pipe_svd_tfidf = make_pipeline(CountVectorizer(),
                     TfidfTransformer(),
                     TruncatedSVD(n_components=300))
pipe_svd_tfidf.fit(X_train['sentence'])
feat_train_svd_tfidf = pipe_svd_tfidf.transform(X_train['sentence'])
feat_test_svd_tfidf = pipe_svd_tfidf.transform(X_test['sentence'])

# %%
param_grid = {'penalty' : ['l1', 'l2']}

lr = LogisticRegression(random_state=42)

lr_grid = GridSearchCV(lr, param_grid, cv = 3)

# %time LR = lr_grid.fit(feat_train_svd_tfidf, y_train)

print(lr_grid.best_score_.round(5))
print(lr_grid.best_params_)

# %%
final_model = lr_grid.best_estimator_

pred_train = final_model.predict(feat_train_svd_tfidf) 
pred_test = final_model.predict(feat_test_svd_tfidf)

# %%
print(classification_report(y_train, pred_train))

# %%
print(classification_report(y_test, pred_test))

# %%
#deacc=True, enlève les ponctuations
from gensim.utils import tokenize
sentance = [list(tokenize(s, deacc=True, lower=True)) for s in X_train['sentence']]
sentance[0]

# %%
#word2vec, réductions des dimensions
#paramètre : https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
#size : the size of the dense vector to represent each token or word 
#window : the maximum distance between the target word and its neighboring word
#min_count : minimium frequency count of words, the model would ignore words that do not satisfy the min_count
#iter : number of iterations (epochs) over the corpus
from gensim.models import word2vec
model = word2vec.Word2Vec(sentance, size=300, window=20,
                          min_count=2, workers=1, iter=100)
model.corpus_count

# %%
"""The vocabulary is in the vocab field of the Word2Vec model's wv property, as a dictionary, 
with the keys being each token (word)"""
vocab = model.wv.vocab
list(vocab)[:5]

# %%
model.wv.vectors.shape

# %%
model.save('trained_word2vec.bin')

# %%
model.most_similar('bien')

# %%
#Les dix premières coordonnées du vecteur associé au mot fabuleux
model.wv['fabuleux'].shape, model.wv['fabuleux'][:10]

# %%
try:
    model.wv['rrrrrrrr']
except KeyError as e:
    print(e)

# %%
import numpy as np
#somme des vecteurs associés aux mots
def get_vect(word, model):
    try:
        return model.wv[word]
    except KeyError:
        return np.zeros((model.vector_size,))

def sum_vectors(phrase, model):
    return sum(get_vect(w, model) for w in phrase)

def word2vec_features(X, model):
    feats = np.vstack([sum_vectors(p, model) for p in X])
    return feats

wv_train_feat = word2vec_features(X_train["sentence"], model)
wv_train_feat.shape

# %%
clfwv = LogisticRegression(solver='lbfgs', max_iter=1000)
clfwv.fit(wv_train_feat, y_train)

# %%
wv_test_feat = word2vec_features(X_test["sentence"], model)

# %%
clfwv.score(wv_test_feat, y_test)

# %%
words = list(sorted(model.wv.vocab))
words[:10]

# %%
subset = ['exceptionnel', 'personnel', words[3], words[4], words[5]]
rows = []
for w in subset:
    for ww in subset:
        rows.append(dict(w1=w, w2=ww, d=model.wv.similarity(w, ww)))
import pandas
pandas.DataFrame(rows).pivot("w1", "w2", "d")

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.syn0norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(wv.vector_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, post) for post in text_list ])

# %% [markdown]
# #####
